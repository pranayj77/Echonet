# %%
import numpy as np
import pandas as pd 
import cv2

# %%
measurments_df = pd.read_csv('/athena/sablab/scratch/bcl2004/datasets/echonet/EchoNet-LVH/MeasurementsList.csv')

# %%
results_df = pd.read_csv('./Inference/0XFCE9C3251F3E58A9/0XFCE9C3251F3E58A9.csv')

# %%
measurments_df
# Out:
#        Unnamed: 0      HashedFileName   Calc  CalcValue  Frame   X1   X2   Y1  \
# 0               1  0X66EFA90ADBC0BA4F   IVSd   0.838136     94  634  659  314
# 1               2  0X66EFA90ADBC0BA4F  LVPWd   0.828865     94  512  529  571
# 2               3  0X66EFA90ADBC0BA4F  LVIDd   5.453681     94  530  634  535
# 3               4  0XAD41A03F4A5B9ABC  LVPWd   0.761081    101  465  491  524
# 4               5  0XAD41A03F4A5B9ABC  LVIDs   2.721935    119  495  578  451
# ...           ...                 ...    ...        ...    ...  ...  ...  ...
# 46694       46695  0X1ED05E23735FBF84  LVPWd   0.603678    190  468  479  489
# 46695       46696  0XB522F9C3DCF9FB3F  LVIDd   3.908540     34  411  502  485
# 46696       46697  0XB522F9C3DCF9FB3F  LVPWd   0.889633     34  391  411  527
# 46697       46698  0XB522F9C3DCF9FB3F  LVIDs   2.493045     48  403  468  422
# 46698       46699  0XB522F9C3DCF9FB3F   IVSd   0.804125     34  502  520  303
#
# ...

# %%
results_df[50:60]
# Out:
#     Unnamed: 0  frame          X1          Y1          X2          Y2  \
# 50          50     50  280.363890  280.363890  347.519999  294.434363
# 51          51     51  281.358496  281.358496  348.580738  293.649810
# 52          52     52  282.515716  282.515716  348.781512  293.973877
# 53          53     53  281.011519  281.011519  347.929717  293.681511
# 54          54     54  284.075595  284.075595  347.531389  296.089684
# 55          55     55  284.338923  284.338923  346.420573  296.116407
# 56          56     56  285.458190  285.458190  347.181338  297.341478
# 57          57     57  286.748491  286.748491  346.768734  298.383087
# 58          58     58  287.221979  287.221979  345.331757  298.342166
# 59          59     59  285.617378  285.617378  344.609832  297.048354
#
#             Y3          X4          Y4       LVPW       LVID        IVS  \
# 50  347.519999  362.500653  362.500653  29.329968  92.209505  25.439224
# ...

# %%
92.355/2.803
# Out:
# 32.94862647163753

# %%
25.988/1.15
# Out:
# 22.59826086956522
